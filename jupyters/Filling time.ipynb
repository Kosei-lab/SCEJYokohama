# %%
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import rc
import numpy as np
import pandas as pd

# %%
matplotlib.font_manager.weight_dict["roman"]
matplotlib.font_manager._rebuild()

# %%
ls
# Out:
#  ドライブ C のボリューム ラベルは Windows です
#  ボリューム シリアル番号は A259-C309 です
#
#  C:\Users\gedo2\Desktop\SCEJYokohama\jupyters のディレクトリ
#
# 2019/07/12  15:39    <DIR>          .
# 2019/07/12  15:39    <DIR>          ..
# 2019/07/12  15:36    <DIR>          .ipynb_checkpoints
# 2019/07/01  09:11           114,560 100-800_空気体積ー.xlsx
# 2019/03/22  18:44            24,903 100-800_充填速度.xlsx
# 2019/07/01  11:15            76,154 100-800_粒子数&流入量.xlsx
# 2019/07/12  15:39           262,668 Filling time.ipynb
# 2019/07/05  17:14           227,147 fillingTime.png
# 2019/07/02  18:06             8,292 fillingTime.xlsx
# 2019/07/05  17:14           452,482 flux.ipynb
# 2019/07/05  17:13           366,993 flux.png
# 2019/07/01  11:15             9,489 flux.xlsx
#                9 個のファイル           1,542,688 バイト
#                3 個のディレクトリ  84,272,263,168 バイトの空き領域

# %%
df = pd.read_excel("fillingTime.xlsx")

# %%
df
# Out:
#   velocity   100    200    300    400    500    600    700   800
# 0     time  0.23  0.184  0.174  0.166  0.162  0.166  0.174  0.17

# %%
sr = df.stack()

# %%
time = sr.values.tolist()
time = time[1:8]
time
# Out:
# [0.23, 0.184, 0.174, 0.166, 0.162, 0.166, 0.174]

# %%
velocity = [100, 200, 300, 400, 500, 600, 700]
velocity
# Out:
# [100, 200, 300, 400, 500, 600, 700]

# %%
gravityTime = 0.21

# %%
def plotGraphs():
    plt.scatter(velocity, time, marker="o", s=200, linewidths=1, edgecolor="black", facecolor="None",label="Suciton filling")
    #plt.plot(np.arange(0,800,10), [gravityTime]*80, linestyle="dashed", color="black", label="Gravity filling")
    
    #plt.legend(fontsize=14)
    
    plt.savefig("fillingTime.png", dpi=500)
    plt.show()

# %%
fig = plt.figure(figsize=(8,6), dpi=500)
ax = fig.add_subplot(1,1,1)


ax.set_xlabel("Velocity [m/s]", fontsize=14)
ax.set_ylabel("Time [s]", fontsize=14)
ax.set_xlim([0, 750])

ax.grid()


plt.rcParams['font.size'] = 14
plt.rcParams["font.family"] = "Times New Roman"
plt.rcParams["xtick.direction"] = "in"
plt.rcParams["ytick.direction"] = "in"
plt.rcParams["axes.linewidth"] = 1.0

plt.tick_params(labelsize=14)

plotGraphs()
